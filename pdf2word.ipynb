# %%
# %pip install pdf2docx
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 2.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 kB 2.5 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 MB 8.0 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 9.1 MB/s eta 0:00:0000:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.8/30.8 MB 9.9 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.6/239.6 kB 6.5 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 9.5 MB/s eta 0:00:00:00:0100:01
# ...
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117029 sha256=686cb6389498057ab308722c8c9f40f5b2566344e589be45f1cfc0e55de5d442
#   Stored in directory: /home/ankan_opencv/.cache/pip/wheels/ec/ce/ba/9d5764d2266c500c18776c7d8f1e3c023075994cbc6dea47db
# Successfully built fire
# ...

# %%
from pdf2docx import Converter

def pdf_to_word(pdf_file_path, word_file_path):
    cv = Converter(pdf_file_path)
    cv.convert(word_file_path, start=0, end=None)
    cv.close()
    print(f"Converted {pdf_file_path} to {word_file_path}")

# Example usage
pdf_to_word('/home/ankan_opencv/officework/VS_Code/caffe-dnn/test.pdf', 'output.docx')
# Out:
# [INFO] Start to convert /home/ankan_opencv/officework/VS_Code/caffe-dnn/test.pdf
# [INFO] [1/4] Opening document...
# [INFO] [2/4] Analyzing document...
# [WARNING] Ignore Line "qϕ(z|x)" due to overlap
# [WARNING] Ignore Line "1" due to overlap
# [WARNING] Ignore Line "2c2" due to overlap
# [WARNING] Ignore Line "2σ2" due to overlap
# [WARNING] Ignore Line "2σ2" due to overlap
# [WARNING] Ignore Line "2" due to overlap
# [WARNING] Ignore Line "detΣ0" due to overlap
# [WARNING] Ignore Line "2" due to overlap
# [WARNING] Ignore Line "." due to overlap
# [WARNING] Ignore Line "." due to overlap
# [WARNING] Ignore Line "lim" due to overlap
# [WARNING] Ignore Line "." due to overlap
# [WARNING] Ignore Line "." due to overlap
# [WARNING] Ignore Line "p(xt−1|xt)" due to overlap
# [WARNING] Ignore Line "aT" due to overlap
# [WARNING] Ignore Line "√αt" due to overlap
# [WARNING] Ignore Line "t" due to overlap
# [WARNING] Ignore Line "t" due to overlap
# ...

# %%
# !pip install pypandoc

# %%
import pypandoc

def word_to_pdf(docx_file_path, pdf_file_path):
    output = pypandoc.convert_file(docx_file_path, 'pdf', outputfile=pdf_file_path)
    assert output == ""
    print(f"Converted {docx_file_path} to {pdf_file_path}")

# Example usage
word_to_pdf('output.docx', 'final_output.pdf')
